# %%
import pandas as pd
import matplotlib.pyplot as plt

prediction_mapping = pd.read_csv('../data/prediction_mapping.csv')
test2024 = pd.read_csv('DEADGE_Christian.csv')
deadge2025 = pd.read_csv('DEADGE_Christian_fallbacks.csv')


test2024 = test2024[test2024["predicted_weight"]>0]
deadge2025 = deadge2025[deadge2025["predicted_weight"]>0]

test2024 = test2024.merge(prediction_mapping, on="ID", how="left")

test2024_agg = test2024[["ID", "predicted_weight", "rm_id"]]
deadge2025_agg = deadge2025[["ID", "rm_id", "predicted_weight"]]


test2024_agg = test2024.groupby("rm_id", as_index=False).agg({
        "predicted_weight": "max",
        }).sort_values("predicted_weight", ascending=False)
deadge2025_agg = deadge2025.groupby("rm_id", as_index=False).agg({
        "predicted_weight": "max",
        }).sort_values("predicted_weight", ascending=False) 


merged = test2024_agg.merge(deadge2025_agg, on="rm_id", suffixes=("_test2024", "_deadge2025"), how="outer")

# sort merged by predicted_weight_test2024 descending
merged = merged.sort_values("predicted_weight_test2024", ascending=False)
print(merged)
# Out:
#     rm_id  predicted_weight_test2024  predicted_weight_deadge2025
# 3    2130               7.573791e+06                 7.573791e+06
# 26   3865               4.815559e+06                 4.815559e+06
# 16   3126               3.542542e+06                 3.542542e+06
# 25   3781               2.961911e+06                 2.961911e+06
# 15   3125               2.186960e+06                 2.186960e+06
# 12   3122               1.925672e+06                 1.925672e+06
# 14   3124               1.613447e+06                 1.613447e+06
# 13   3123               1.504917e+06                 1.504917e+06
# 18   3282               9.253088e+05                 9.253088e+05
# 27   3901               8.611696e+05                 8.611696e+05
# 8    2142               1.740279e+05                 1.740279e+05
# 21   3421               7.173167e+04                 7.173167e+04
# 9    2143               8.682041e+01                 8.682041e+01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

prediction_mapping = pd.read_csv('../data/prediction_mapping.csv')
test2024 = pd.read_csv('test2024.csv')
deadge2025 = pd.read_csv('DEADGE_submissionV3.csv')

test2024 = test2024[test2024["predicted_weight"]>0]
deadge2025 = deadge2025[deadge2025["predicted_weight"]>0]

test2024 = test2024.merge(prediction_mapping, on="ID", how="left")

test2024_agg = test2024[["ID", "predicted_weight", "rm_id"]]
deadge2025_agg = deadge2025[["ID", "rm_id", "predicted_weight"]]


test2024_agg = test2024.groupby("rm_id", as_index=False).agg({
        "predicted_weight": "max",
        }).sort_values("predicted_weight", ascending=False)
deadge2025_agg = deadge2025.groupby("rm_id", as_index=False).agg({
        "predicted_weight": "max",
        }).sort_values("predicted_weight", ascending=False) 


merged = test2024_agg.merge(deadge2025_agg, on="rm_id", suffixes=("_test2024", "_deadge2025"), how="outer")

# sort merged by predicted_weight_test2024 descending
merged = merged.sort_values("predicted_weight_test2024", ascending=False)
print(merged)
# Out:
#     rm_id  predicted_weight_test2024  predicted_weight_deadge2025
# 36   3781                  4569612.6                 3.970443e+06
# 37   3865                  4060750.4                 4.112868e+06
# 4    2130                  2484792.8                 4.895138e+06
# 22   3125                  2119782.0                 1.854809e+06
# 23   3126                  2099090.0                 2.991925e+06
# 21   3124                  1685474.0                 1.546513e+06
# 27   3282                  1661156.0                 1.592118e+06
# 19   3122                  1528324.0                 1.676793e+06
# 20   3123                  1248016.0                 1.463938e+06
# 10   2140                   732508.0                          NaN
# 39   3901                   600516.0                 1.217531e+06
# 8    2134                   428992.2                 1.095899e+05
# 26   3265                   403298.0                          NaN
# ...

# %%
best = pd.read_csv('DEADGE_Christian.csv')
test2024 = pd.read_csv('test2024.csv')

best = best.merge(prediction_mapping, on="ID", how="left")


fallbacks = [2124, 2131, 2133, 2134, 2135, 2145, 2161, 3201, 3362, 3381, 3581, 3601, 3621, 4044, 4081, 4161, 4222, 4302]

for rm_id in fallbacks:
    # Find IDs corresponding to this rm_id
    ids = prediction_mapping[prediction_mapping["rm_id"] == rm_id]["ID"].tolist()
    for id in ids:
        # Put predicted_weight from test2024 into best
        weight = test2024[test2024["ID"] == id]["predicted_weight"]
        best.loc[best["ID"] == id, "predicted_weight"] = weight

best.to_csv('DEADGE_Christian_fallbacks.csv', index=False)
